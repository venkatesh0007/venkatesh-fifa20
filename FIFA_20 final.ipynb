# %%
## Importing the libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv('players_20.csv')

# %%
data.shape
# Out:
# (18278, 104)

# %%
col=list(data.columns)
print(col)
# Out:
# ['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'powe
# ...

# %%
data.iloc[:,20:40]
# Out:
#         body_type real_face  release_clause_eur  \
# 0           Messi       Yes         195800000.0
# 1      C. Ronaldo       Yes          96500000.0
# 2          Neymar       Yes         195200000.0
# 3          Normal       Yes         164700000.0
# 4          Normal       Yes         184500000.0
# ...           ...       ...                 ...
# 18273      Normal        No             70000.0
# 18274      Normal        No             72000.0
# 18275        Lean        No             70000.0
# 18276        Lean        No             70000.0
# 18277      Normal        No                 NaN
#
#                                              player_tags team_position  \
# 0      #Dribbler, #Distance Shooter, #Crosser, #FK Sp...            RW
# 1      #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2      #Speedster, #Dribbler, #Playmaker  , #Crosser,...           CAM
# 3                                                    NaN            GK
# ...

# %%
data.iloc[:,54:70]
# Out:
#        movement_acceleration  movement_sprint_speed  movement_agility  \
# 0                         91                     84                93
# 1                         89                     91                87
# 2                         94                     89                96
# 3                         43                     60                67
# 4                         94                     88                95
# ...                      ...                    ...               ...
# 18273                     56                     58                45
# 18274                     55                     61                43
# 18275                     55                     54                52
# 18276                     55                     63                55
# 18277                     54                     64                52
#
#        movement_reactions  movement_balance  power_shot_power  power_jumping  \
# ...

# %%
data.iloc[:,70:76]
# Out:
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                     33                         37                        26
# 1                     28                         32                        24
# 2                     27                         26                        29
# 3                     27                         12                        18
# 4                     34                         27                        22
# ...                  ...                        ...                       ...
# 18273                 45                         50                        52
# 18274                 42                         53                        57
# 18275                 46                         52                        46
# 18276                 39                         44                        54
# 18277                 52                         42                        48
#
# ...

# %% [markdown]
# # DOMAIN ANALYSIS

# %% [markdown]
# # DOMAIN ANALYSIS
#
# ## LS
# - LS stands for Long Snapper (football).
#
# ## ST
# - Striker. A similar function as the center and wing forward. IF – Inside forward. In the old days an offensive line could consist of five attackers and include two inside forwards positioned between the wing forwards and the center forward and normally a little behind the other three.
# ## RS
# - In soccer, the abbreviation “RS” means Right Striker. The right striker(RS) is positioned on the right-hand side of the forward players near the opposition's goal.
# ## LW
# - LW – left wing. Similar to the left wing back, but usually with a primarily offensive task. In other words, an offensive wing midfielder.
# ## LF
# - In soccer, the abbreviation “LF” means Left Forward. The left forward(LF) is positioned on the left-hand side of the team's attacking line.
# ## CF
# - center forward. The attacker that is positioned in the middle of the offensive line. In modern football it has become common to only use one or two attackers; therefore a center forward may not be quite relevant as a description
# ## RF
# - Well RF/LF stands for Right Forward and Left Forward. Forward meaning striker. The wide attacking midfielders are usually the ones to feed the ball to forwards and sit deeper in field. Alex Iwobi is an example of a wide attacking midfielder, whereas Gareth Bale is an example of an RF.
# ## RW
# - RW – right wing. The same as the left wing, but on the opposite wing. M – midfielder. WF – wing forward. An attacker in offensive position on the wing.
# ## LAM
# - LAM Left attacking midfield.
# ## CAM
# - The Central Attacking Midfielder, or CAM, on a team, is positioned in the center of the soccer field just behind the forwards. Their role is to assist and support the forwards on their team in an attack on the opposition goal
# ## RAM
# - Right (off-centre) Attacking Midfielder)
# ## LM
# - In soccer, the abbreviation “LM” means Left Midfielder. ... The left midfielder(LM) is often one of the fastest players on a team and is skilled at crossing the ball.
# ## LCM
# - Left (off-centre) Centre Midfielder
# ## CM
# - CM – center midfielder.
# ## RCM
# - Right (off-centre) Centre Midfielder
#
# ## RM
# - Right Midfielder.
#
# ## LWB
# - Another name for the defensive player that either plays on the left side (left back) or the right side (right back). LWB – left wing back. Positioned in front of the left back and out on the “wing”
# ## LDM
# -  Left (off-centre) Defensive Midfielder.
# ## CDM
# - Central Defensive Midfielder.
# ## RDM
# - Right (off-centre) Defensive Midfielder.
# ## RWB
# - RWB – right wing back. Positioned in front of the right back. D – defender. DM – defensive midfielder. ... In other words, an offensive wing midfielder.
# ## LB
# - A linebacker (LB or backer) is a playing position in gridiron football. Linebackers are members of the defensive team, and line up approximately three to five yards (4 m) behind the line of scrimmage and behind the defensive linemen.
# ## LCB
# - In soccer, the abbreviation “LCB” means Left Center Back. ... The role of the left-center back(LCB) is to defend the left-hand side of the soccer field and prevent any opposition players, or the soccer ball, from getting past them.
# ## CB
# - The job of the centre-back, (or central defender) (historically called a centre-half) is to stop opposing players, particularly the strikers, from scoring, and to bring the ball out from their penalty area. As their name suggests, they play in a central position.
# ## RCB
# - Right Cornerback.
# ## RB
# - A running back (RB) is a member of the offensive backfield in gridiron football. The primary roles of a running back are to receive handoffs from the quarterback to rush the ball, to line up as a receiver to catch the ball, and block.

# %% [markdown]
# # BASIC CHECKS

# %%
data.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
data.tail()
# Out:
#        sofifa_id                                         player_url  \
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name     long_name  age         dob  height_cm  weight_kg  \
# 18273    Shao Shuai            邵帅   22  1997-03-10        186         79
# 18274  Xiao Mingjie  Mingjie Xiao   22  1997-01-01        177         66
# 18275     Zhang Wei            张威   19  2000-05-16        186         75
# 18276  Wang Haijian           汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing           潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
data.shape
# Out:
# (18278, 104)

# %%
data.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   18278.000000  18278.000000  18278.000000  18278.000000  18278.000000
# mean   219738.864482     25.283291    181.362184     75.276343     66.244994
# std     27960.200461      4.656964      6.756961      7.047744      6.949953
# min       768.000000     16.000000    156.000000     50.000000     48.000000
# 25%    204445.500000     22.000000    177.000000     70.000000     62.000000
# 50%    226165.000000     25.000000    181.000000     75.000000     66.000000
# 75%    240795.750000     29.000000    186.000000     80.000000     71.000000
# max    252905.000000     42.000000    205.000000    110.000000     94.000000
#
#           potential     value_eur       wage_eur  international_reputation  \
# count  18278.000000  1.827800e+04   18278.000000              18278.000000
# mean      71.546887  2.484038e+06    9456.942773                  1.103184
# ...

# %%
data.describe(include='O')
# Out:
#                                                player_url    short_name  \
# count                                               18278         18278
# unique                                              18278         17354
# top     https://sofifa.com/player/222477/louis-reed/20...  J. Rodríguez
# freq                                                    1            11
#
#          long_name         dob nationality         club player_positions  \
# count        18278       18278       18278        18278            18278
# unique       18218        6142         162          698              643
# top     Liam Kelly  1992-02-29     England  Bournemouth               CB
# freq             3         113        1667           33             2322
#
#        preferred_foot      work_rate body_type  ...    lwb    ldm    cdm  \
# count           18278          18278     18278  ...  16242  16242  16242
# unique              2              9        10  ...     98     98     98
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 14.5+ MB

# %% [markdown]
# # EDA

# %%
import sweetviz as sv

# %%
report=sv.analyze(data)
report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Preprocessing

# %%
data.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            2036
# lcb           2036
# cb            2036
# rcb           2036
# rb            2036
# Length: 104, dtype: int64

# %%
col=list(data.columns)
print(col)
# Out:
# ['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'powe
# ...

# %%
df1=data.drop(columns={'dob','player_tags','team_jersey_number','player_url','sofifa_id'},axis=1)

# %%
df1.head()
# Out:
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32        170
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34        187
# 2          Neymar Jr        Neymar da Silva Santos Junior   27        175
# 3           J. Oblak                            Jan Oblak   26        188
# 4          E. Hazard                          Eden Hazard   28        175
#
#    weight_kg nationality                 club  overall  potential  value_eur  \
# 0         72   Argentina         FC Barcelona       94         94   95500000
# 1         83    Portugal             Juventus       93         93   58500000
# 2         68      Brazil  Paris Saint-Germain       92         92  105500000
# 3         87    Slovenia      Atlético Madrid       91         93   77500000
# 4         74     Belgium          Real Madrid       91         91   90000000
#
# ...

# %%
df2=df1.iloc[:,0:20]

# %%
df2.head()
# Out:
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32        170
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34        187
# 2          Neymar Jr        Neymar da Silva Santos Junior   27        175
# 3           J. Oblak                            Jan Oblak   26        188
# 4          E. Hazard                          Eden Hazard   28        175
#
#    weight_kg nationality                 club  overall  potential  value_eur  \
# 0         72   Argentina         FC Barcelona       94         94   95500000
# 1         83    Portugal             Juventus       93         93   58500000
# 2         68      Brazil  Paris Saint-Germain       92         92  105500000
# 3         87    Slovenia      Atlético Madrid       91         93   77500000
# 4         74     Belgium          Real Madrid       91         91   90000000
#
# ...

# %%
df2.isnull().sum()
# Out:
# short_name                     0
# long_name                      0
# age                            0
# height_cm                      0
# weight_kg                      0
# nationality                    0
# club                           0
# overall                        0
# potential                      0
# value_eur                      0
# wage_eur                       0
# player_positions               0
# preferred_foot                 0
# international_reputation       0
# weak_foot                      0
# skill_moves                    0
# work_rate                      0
# body_type                      0
# real_face                      0
# release_clause_eur          1298
# dtype: int64

# %% [markdown]
# imputing mean value to release_clause_eur

# %%
data['release_clause_eur'].fillna(data['release_clause_eur'].median,inplace=True)

# %%
data.release_clause_eur.isnull().sum()
# Out:
# 0

# %%
df3=df1.iloc[:,20:40]

# %%
df3.head()
# Out:
#   team_position loaned_from      joined  contract_valid_until nation_position  \
# 0            RW         NaN  2004-07-01                2021.0             NaN
# 1            LW         NaN  2018-07-10                2022.0              LS
# 2           CAM         NaN  2017-08-03                2022.0              LW
# 3            GK         NaN  2014-07-16                2023.0              GK
# 4            LW         NaN  2019-07-01                2024.0              LF
#
#    nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 0                   NaN  87.0      92.0     92.0       96.0       39.0
# 1                   7.0  90.0      93.0     82.0       89.0       35.0
# 2                  10.0  91.0      85.0     87.0       95.0       32.0
# 3                   1.0   NaN       NaN      NaN        NaN        NaN
# 4                  10.0  91.0      83.0     86.0       94.0       35.0
#
# ...

# %%
df3.isnull().sum()
# Out:
# team_position             240
# loaned_from             17230
# joined                   1288
# contract_valid_until      240
# nation_position         17152
# nation_jersey_number    17152
# pace                     2036
# shooting                 2036
# passing                  2036
# dribbling                2036
# defending                2036
# physic                   2036
# gk_diving               16242
# gk_handling             16242
# gk_kicking              16242
# gk_reflexes             16242
# gk_speed                16242
# gk_positioning          16242
# player_traits           10712
# attacking_crossing          0
# dtype: int64

# %%
df3=df3.drop(columns={'team_position','loaned_from','joined','contract_valid_until','nation_position','nation_jersey_number'},axis=1)

# %%
df3.head()
# Out:
#    pace  shooting  passing  dribbling  defending  physic  gk_diving  \
# 0  87.0      92.0     92.0       96.0       39.0    66.0        NaN
# 1  90.0      93.0     82.0       89.0       35.0    78.0        NaN
# 2  91.0      85.0     87.0       95.0       32.0    58.0        NaN
# 3   NaN       NaN      NaN        NaN        NaN     NaN       87.0
# 4  91.0      83.0     86.0       94.0       35.0    66.0        NaN
#
#    gk_handling  gk_kicking  gk_reflexes  gk_speed  gk_positioning  \
# 0          NaN         NaN          NaN       NaN             NaN
# 1          NaN         NaN          NaN       NaN             NaN
# 2          NaN         NaN          NaN       NaN             NaN
# 3         92.0        78.0         89.0      52.0            90.0
# 4          NaN         NaN          NaN       NaN             NaN
#
#                                        player_traits  attacking_crossing
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# ...

# %%
df3.shape
# Out:
# (18278, 14)

# %%
df3.isnull().sum()
# Out:
# pace                   2036
# shooting               2036
# passing                2036
# dribbling              2036
# defending              2036
# physic                 2036
# gk_diving             16242
# gk_handling           16242
# gk_kicking            16242
# gk_reflexes           16242
# gk_speed              16242
# gk_positioning        16242
# player_traits         10712
# attacking_crossing        0
# dtype: int64

# %% [markdown]
# filling the missing values of the goal keepers in the players section with value 0

# %%
df3['pace'].fillna(value=0,inplace=True)

# %%
df3['shooting'].fillna(value=0,inplace=True)

# %%
df3['passing'].fillna(value=0,inplace=True)

# %%
df3['dribbling'].fillna(value=0,inplace=True)

# %%
df3['defending'].fillna(value=0,inplace=True)

# %%
df3['physic'].fillna(value=0,inplace=True)

# %% [markdown]
# filling the missing values of the players in the goal keeping section with value 0

# %%
df3['gk_diving'].fillna(value=0,inplace=True)
df3['gk_handling'].fillna(value=0,inplace=True)
df3['gk_kicking'].fillna(value=0,inplace=True)
df3['gk_reflexes'].fillna(value=0,inplace=True)
df3['gk_speed'].fillna(value=0,inplace=True)
df3['gk_positioning'].fillna(value=0,inplace=True)

# %%
df3.player_traits.value_counts()
# Out:
# Early Crosser                                                                                                                        501
# Power Free-Kick                                                                                                                      370
# Long Passer (CPU AI Only)                                                                                                            354
# Crowd Favourite                                                                                                                      296
# Argues with Officials                                                                                                                294
#                                                                                                                                     ...
# Diver, Long Passer (CPU AI Only), Giant Throw-in, Outside Foot Shot                                                                    1
# ...

# %%
df3=df3.drop('player_traits',axis=1)

# %%
df3.isnull().sum()
# Out:
# pace                  0
# shooting              0
# passing               0
# dribbling             0
# defending             0
# physic                0
# gk_diving             0
# gk_handling           0
# gk_kicking            0
# gk_reflexes           0
# gk_speed              0
# gk_positioning        0
# attacking_crossing    0
# dtype: int64

# %%
df4=df1.iloc[:,40:70]
df4.head()
# Out:
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   11                          15                       43
# 4                   84                          61                       89
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 13               12           13                 14
# 4                 83               95           83                 79
#
#    skill_long_passing  skill_ball_control  movement_acceleration  ...  \
# ...

# %%
df4.isnull().sum()
# Out:
# attacking_finishing           0
# attacking_heading_accuracy    0
# attacking_short_passing       0
# attacking_volleys             0
# skill_dribbling               0
# skill_curve                   0
# skill_fk_accuracy             0
# skill_long_passing            0
# skill_ball_control            0
# movement_acceleration         0
# movement_sprint_speed         0
# movement_agility              0
# movement_reactions            0
# movement_balance              0
# power_shot_power              0
# power_jumping                 0
# power_stamina                 0
# power_strength                0
# power_long_shots              0
# mentality_aggression          0
# mentality_interceptions       0
# mentality_positioning         0
# mentality_vision              0
# mentality_penalties           0
# mentality_composure           0
# defending_marking             0
# defending_standing_tackle     0
# defending_sliding_tackle      0
# goalkeeping_diving            0
# ...

# %%
df5=df1.iloc[:,70:]
df5
# Out:
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes  \
# 0                       15                       14                     8
# 1                       15                       14                    11
# 2                       15                       15                    11
# 3                       78                       90                    89
# 4                        6                        8                     8
# ...                    ...                      ...                   ...
# 18273                   13                        5                    14
# 18274                   14                       11                     9
# 18275                   10                        6                    14
# 18276                   13                       13                    13
# 18277                   14                        9                    10
#
#          ls    st    rs    lw    lf    cf    rf  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
df5.isnull().sum()
# Out:
# goalkeeping_kicking           0
# goalkeeping_positioning       0
# goalkeeping_reflexes          0
# ls                         2036
# st                         2036
# rs                         2036
# lw                         2036
# lf                         2036
# cf                         2036
# rf                         2036
# rw                         2036
# lam                        2036
# cam                        2036
# ram                        2036
# lm                         2036
# lcm                        2036
# cm                         2036
# rcm                        2036
# rm                         2036
# lwb                        2036
# ldm                        2036
# cdm                        2036
# rdm                        2036
# rwb                        2036
# lb                         2036
# lcb                        2036
# cb                         2036
# rcb                        2036
# rb                         2036
# ...

# %%
data1=pd.concat([df2,df3,df4,df5],axis=1)

# %%
data1.head()
# Out:
#           short_name                            long_name  age  height_cm  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32        170
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34        187
# 2          Neymar Jr        Neymar da Silva Santos Junior   27        175
# 3           J. Oblak                            Jan Oblak   26        188
# 4          E. Hazard                          Eden Hazard   28        175
#
#    weight_kg nationality                 club  overall  potential  value_eur  \
# 0         72   Argentina         FC Barcelona       94         94   95500000
# 1         83    Portugal             Juventus       93         93   58500000
# 2         68      Brazil  Paris Saint-Germain       92         92  105500000
# 3         87    Slovenia      Atlético Madrid       91         93   77500000
# 4         74     Belgium          Real Madrid       91         91   90000000
#
# ...

# %%
col1=list(data1.columns)
print(col1)
# Out:
# ['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_
# ...

# %%
data1.describe(include='O')
# Out:
#           short_name   long_name nationality         club player_positions  \
# count          18278       18278       18278        18278            18278
# unique         17354       18218         162          698              643
# top     J. Rodríguez  Liam Kelly     England  Bournemouth               CB
# freq              11           3        1667           33             2322
#
#        preferred_foot      work_rate body_type real_face     ls  ...    lwb  \
# count           18278          18278     18278     18278  16242  ...  16242
# unique              2              9        10         2     94  ...     98
# top             Right  Medium/Medium    Normal        No   61+2  ...   59+2
# freq            13960           9875     10750     16310    725  ...    682
#
#           ldm    cdm    rdm    rwb     lb    lcb     cb    rcb     rb
# count   16242  16242  16242  16242  16242  16242  16242  16242  16242
# ...

# %%
data2=data1.drop(columns={'long_name'},axis=1)

# %%
data2.head()
# Out:
#           short_name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   32        170         72   Argentina
# 1  Cristiano Ronaldo   34        187         83    Portugal
# 2          Neymar Jr   27        175         68      Brazil
# 3           J. Oblak   26        188         87    Slovenia
# 4          E. Hazard   28        175         74     Belgium
#
#                   club  overall  potential  value_eur  wage_eur  ...   lwb  \
# 0         FC Barcelona       94         94   95500000    565000  ...  68+2
# 1             Juventus       93         93   58500000    405000  ...  65+3
# 2  Paris Saint-Germain       92         92  105500000    290000  ...  66+3
# 3      Atlético Madrid       91         93   77500000    125000  ...   NaN
# 4          Real Madrid       91         91   90000000    470000  ...  66+3
#
#     ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %%
data2.describe(include='O')
# Out:
#           short_name nationality         club player_positions preferred_foot  \
# count          18278       18278        18278            18278          18278
# unique         17354         162          698              643              2
# top     J. Rodríguez     England  Bournemouth               CB          Right
# freq              11        1667           33             2322          13960
#
#             work_rate body_type real_face     ls     st  ...    lwb    ldm  \
# count           18278     18278     18278  16242  16242  ...  16242  16242
# unique              9        10         2     94     94  ...     98     98
# top     Medium/Medium    Normal        No   61+2   61+2  ...   59+2   59+2
# freq             9875     10750     16310    725    725  ...    682    636
#
#           cdm    rdm    rwb     lb    lcb     cb    rcb     rb
# count   16242  16242  16242  16242  16242  16242  16242  16242
# unique     98     98     98     96    110    110    110     96
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data2.short_name=le.fit_transform(data2.short_name)
data2.nationality=le.fit_transform(data2.short_name)
data2.club=le.fit_transform(data2.club)
data2.player_positions=le.fit_transform(data2.player_positions)
data2.preferred_foot=le.fit_transform(data2.preferred_foot)
data2.work_rate=le.fit_transform(data2.work_rate)
data2.body_type=le.fit_transform(data2.body_type)
data2.real_face=le.fit_transform(data2.real_face)

# %%
data2.ls.fillna(value='0+0',inplace=True)
data2.st.fillna(value='0+0',inplace=True)
data2.rs.fillna(value='0+0',inplace=True)
data2.lw.fillna(value='0+0',inplace=True)
data2.cf.fillna(value='0+0',inplace=True)
data2.rf.fillna(value='0+0',inplace=True)
data2.lf.fillna(value='0+0',inplace=True)
data2.rw.fillna(value='0+0',inplace=True)
data2.lam.fillna(value='0+0',inplace=True)
data2.cam.fillna(value='0+0',inplace=True)
data2.ram.fillna(value='0+0',inplace=True)
data2.lm.fillna(value='0+0',inplace=True)
data2.lcm.fillna(value='0+0',inplace=True)
data2.cm.fillna(value='0+0',inplace=True)
data2.rcm.fillna(value='0+0',inplace=True)
data2.rm.fillna(value='0+0',inplace=True)
data2.lwb.fillna(value='0+0',inplace=True)
data2.ldm.fillna(value='0+0',inplace=True)
data2.cdm.fillna(value='0+0',inplace=True)
data2.rdm.fillna(value='0+0',inplace=True)
data2.rwb.fillna(value='0+0',inplace=True)
data2.lb.fillna(value='0+0',inplace=True)
data2.lcb.fillna(value='0+0',inplace=True)
data2.cb.fillna(value='0+0',inplace=True)
data2.rcb.fillna(value='0+0',inplace=True)

# %%
data2.rb.fillna(value='0+0',inplace=True)

# %%
data2.iloc[:1,80:]
# Out:
#      rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  92+2  68+2  66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2

# %%
data2['ls'] = data2['ls'].str.replace('+', '.')
data2['st']=data2['st'].str.replace('+','.')
data2['rs']=data2['rs'].str.replace('+','.')
data2['lw']=data2['lw'].str.replace('+','.')
data2['cf']=data2['cf'].str.replace('+','.')
data2['lf']=data2['lf'].str.replace('+','.')
data2['rw']=data2['rw'].str.replace('+','.')
data2['lam']=data2['lam'].str.replace('+','.')
data2['lm']=data2['lm'].str.replace('+','.')
data2['lcm']=data2['lcm'].str.replace('+','.')
data2['cm']=data2['cm'].str.replace('+','.')
data2['rcm']=data2['rcm'].str.replace('+','.')
data2['rm']=data2['rm'].str.replace('+','.')
data2['lwb']=data2['lwb'].str.replace('+','.')
data2['ldm']=data2['ldm'].str.replace('+','.')
data2['cdm']=data2['cdm'].str.replace('+','.')
data2['rdm']=data2['rdm'].str.replace('+','.')
data2['rwb']=data2['rwb'].str.replace('+','.')
data2['lb']=data2['lb'].str.replace('+','.')
data2['lcb']=data2['lcb'].str.replace('+','.')
data2['cb']=data2['cb'].str.replace('+','.')
data2['rcb']=data2['rcb'].str.replace('+','.')
data2['rb']=data2['rb'].str.replace('+','.')

# %%
data2['ls'] = data2['ls'].astype(float)
data2['st']=data2['st'].astype(float)
data2['rs']=data2['rs'].astype(float)
data2['lw']=data2['lw'].astype(float)
data2['cf']=data2['cf'].astype(float)
data2['rw']=data2['rw'].astype(float)
data2['lam']=data2['lam'].astype(float)
data2['lm']=data2['lm'].astype(float)
data2['lcm']=data2['lcm'].astype(float)
data2['cm']=data2['cm'].astype(float)
data2['rcm']=data2['rcm'].astype(float)
data2['rm']=data2['rm'].astype(float)
data2['lwb']=data2['lwb'].astype(float)
data2['ldm']=data2['ldm'].astype(float)
data2['cdm']=data2['cdm'].astype(float)
data2['rdm']=data2['rdm'].astype(float)
data2['rwb']=data2['rwb'].astype(float)
data2['lb']=data2['lb'].astype(float)
data2['lcb']=data2['lcb'].astype(float)
data2['cb']=data2['cb'].astype(float)
data2['rcb']=data2['rcb'].astype(float)
data2['rb']=data2['rb'].astype(float)

# %%
data2['ls'] = data2['ls'].astype(int)
data2['st']=data2['st'].astype(int)
data2['rs']=data2['rs'].astype(int)
data2['lw']=data2['lw'].astype(int)
data2['cf']=data2['cf'].astype(int)
data2['rw']=data2['rw'].astype(int)
data2['lam']=data2['lam'].astype(int)
data2['lm']=data2['lm'].astype(int)
data2['lcm']=data2['lcm'].astype(int)
data2['cm']=data2['cm'].astype(int)
data2['rcm']=data2['rcm'].astype(int)
data2['rm']=data2['rm'].astype(int)
data2['lwb']=data2['lwb'].astype(int)
data2['ldm']=data2['ldm'].astype(int)
data2['cdm']=data2['cdm'].astype(int)
data2['rdm']=data2['rdm'].astype(int)
data2['rwb']=data2['rwb'].astype(int)
data2['lb']=data2['lb'].astype(int)
data2['lcb']=data2['lcb'].astype(int)
data2['cb']=data2['cb'].astype(int)
data2['rcb']=data2['rcb'].astype(int)
data2['rb']=data2['rb'].astype(int)

# %%
data2.lf.fillna(value='0+0',inplace=True)
data2.rf.fillna(value='0+0',inplace=True)
data2.cam.fillna(value='0+0',inplace=True)
data2.ram.fillna(value='0+0',inplace=True)

# %%
data2['lf'] = data2['lf'].str.replace('+', '.')
data2['rf'] = data2['rf'].str.replace('+', '.')
data2['cam'] = data2['cam'].str.replace('+', '.')
data2['ram'] = data2['ram'].str.replace('+', '.')

# %%
data2['lf']=data2['lf'].astype(float)
data2['rf']=data2['rf'].astype(float)
data2['cam']=data2['cam'].astype(float)
data2['ram']=data2['ram'].astype(float)

# %%
data2['lf']=data2['lf'].astype(int)
data2['rf']=data2['rf'].astype(int)
data2['cam']=data2['cam'].astype(int)
data2['ram']=data2['ram'].astype(int)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 91 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   short_name                  18278 non-null  int32
#  1   age                         18278 non-null  int64
#  2   height_cm                   18278 non-null  int64
#  3   weight_kg                   18278 non-null  int64
#  4   nationality                 18278 non-null  int64
#  5   club                        18278 non-null  int32
#  6   overall                     18278 non-null  int64
#  7   potential                   18278 non-null  int64
#  8   value_eur                   18278 non-null  int64
#  9   wage_eur                    18278 non-null  int64
#  10  player_positions            18278 non-null  int32
#  11  preferred_foot              18278 non-null  int32
#  12  international_reputation    18278 non-null  int64
# ...

# %%
#creation of required X
X=data2.values
X
# Out:
# array([[ 9723.,    32.,   170., ...,    52.,    52.,    63.],
#        [ 3164.,    34.,   187., ...,    53.,    53.,    61.],
#        [12658.,    27.,   175., ...,    46.,    46.,    61.],
#        ...,
#        [17252.,    19.,   186., ...,    49.,    49.,    47.],
#        [16760.,    18.,   185., ...,    49.,    49.,    48.],
#        [13452.,    26.,   182., ...,    50.,    50.,    48.]])

# %%
data3=data2.drop('short_name',axis=1,inplace=True)

# %%
#creation of required X
X=data3
X

# %%
data2['pace']=data2['pace'].astype(int)
data2['shooting']=data2['shooting'].astype(int)
data2['passing']=data2['passing'].astype(int)
data2['dribbling']=data2['dribbling'].astype(int)
data2['defending']=data2['defending'].astype(int)
data2['physic']=data2['physic'].astype(int)
data2['gk_diving']=data2['gk_diving'].astype(int)
data2['gk_handling']=data2['gk_handling'].astype(int)
data2['gk_kicking']=data2['gk_kicking'].astype(int)
data2['gk_reflexes']=data2['gk_reflexes'].astype(int)
data2['gk_speed']=data2['gk_speed'].astype(int)

# %%
data2.release_clause_eur.unique()
# Out:
# array([1.958e+08, 9.650e+07, 1.952e+08, ..., 4.000e+04, 6.000e+04,
#        5.900e+04])

# %%
data2['release_clause_eur']=data2['release_clause_eur'].fillna(0).astype(int)

# %%
data2['gk_positioning']=data2['gk_positioning'].astype(int)

# %%
data2.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18278 entries, 0 to 18277
# Data columns (total 90 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         18278 non-null  int64
#  1   height_cm                   18278 non-null  int64
#  2   weight_kg                   18278 non-null  int64
#  3   nationality                 18278 non-null  int64
#  4   club                        18278 non-null  int32
#  5   overall                     18278 non-null  int64
#  6   potential                   18278 non-null  int64
#  7   value_eur                   18278 non-null  int64
#  8   wage_eur                    18278 non-null  int64
#  9   player_positions            18278 non-null  int32
#  10  preferred_foot              18278 non-null  int32
#  11  international_reputation    18278 non-null  int64
#  12  weak_foot                   18278 non-null  int64
# ...

# %%
# Using the elbow method to find  the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=45)
    kmeans.fit(data2)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 2, random_state = 42)
y_kmeans = kmeans.fit_predict(data2)
print(y_kmeans)
# Out:
# [1 1 1 ... 0 0 0]

# %%
# Applying k-means to the cars dataset
kmeans = KMeans(n_clusters=2,init='k-means++',max_iter=300,n_init=10,random_state=64) 
y_kmeans = kmeans.fit_predict(data2)

# %%
print(y_kmeans)
# Out:
# [1 1 1 ... 0 0 0]

# %%
# Visualising the clusters
plt.scatter(data2[y_kmeans == 0,0], data2[y_kmeans == 0,1],s=100,c='red',label='cluster1')
plt.scatter(data2[y_kmeans == 1,0], data2[y_kmeans == 1,1],s=100,c='blue',label='cluster2')
plt.scatter(data2[y_kmeans == 2,0], data2[y_kmeans == 2,1],s=100,c='green',label='cluster3')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow')
plt.title('Clusters of similar players')
plt.legend()
plt.show()

# %%
from sklearn.metrics import silhouette_score
label=kmeans.labels_
label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
score=silhouette_score(data2,label)
score
# Out:
# 0.8896412707360278
